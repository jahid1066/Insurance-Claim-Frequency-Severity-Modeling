# %%
import sys
from pathlib import Path

# Find project root dynamically
current_path = Path().resolve()

for parent in current_path.parents:
    if (parent / "src").exists():
        project_root = parent
        break
else:
    raise RuntimeError("Project root with 'src' folder not found")

sys.path.insert(0, str(project_root))

# %%
from src.preprocessing import prepare_severity_data
from src.models import fit_gamma_glm

# %%
import pandas as pd

df = pd.read_csv("../Data/raw/GLM_example.csv")

# %%
df_sev = prepare_severity_data(df)
df_sev.head()
# Out:
#      ClaimAmount  VehPower  VehAge  DrivAge  BonusMalus  Density
# 66        303.00         7       1       61          50    27000
# 93       1981.84        12       5       50          60       56
# 199      1456.55         4       0       36          85     4792
# 205     10834.00        10       0       51         100    27000
# 223      3986.67         5       0       45          50       12

# %%
X = df_sev[["VehPower", "VehAge", "DrivAge", "BonusMalus", "Density"]]
y = df_sev["ClaimAmount"]

# %%
model_gamma = fit_gamma_glm(X, y)
model_gamma.summary()
# Out:
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\genmod\families\links.py:13: FutureWarning: The log link alias is deprecated. Use Log instead. The log link alias will be removed after the 0.15.0 release.
#   warnings.warn(
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:            ClaimAmount   No. Observations:                24944
# Model:                            GLM   Df Residuals:                    24938
# Model Family:                   Gamma   Df Model:                            5
# Link Function:                    log   Scale:                          14.858
# Method:                          IRLS   Log-Likelihood:            -2.4587e+05
# Date:                Fri, 26 Dec 2025   Deviance:                       37185.
# Time:                        14:55:22   Pearson chi2:                 3.71e+05
# ...
