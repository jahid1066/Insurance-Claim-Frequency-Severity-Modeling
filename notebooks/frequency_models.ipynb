# %%
import sys
from pathlib import Path

# Find project root dynamically
current_path = Path().resolve()

for parent in current_path.parents:
    if (parent / "src").exists():
        project_root = parent
        break
else:
    raise RuntimeError("Project root with 'src' folder not found")

sys.path.insert(0, str(project_root))

# %%
from src.preprocessing import prepare_frequency_data
from src.models import fit_poisson_glm

# %%
import pandas as pd

df = pd.read_csv("../Data/raw/GLM_example.csv")

# %%
df_freq = prepare_frequency_data(df)
df_freq.head()
# Out:
#    ClaimNb  VehPower  VehAge  DrivAge  BonusMalus  Density  log_exposure
# 0        0         5       0       55          50     1217     -2.302585
# 1        0         5       0       55          50     1217     -0.261365
# 2        0         6       2       52          50       54     -0.287682
# 3        0         7       0       46          50       76     -2.407946
# 4        0         7       0       46          50       76     -0.174353

# %%
X = df_freq[["VehPower", "VehAge", "DrivAge", "BonusMalus", "Density"]]
y = df_freq["ClaimNb"]
offset = df_freq["log_exposure"]

# %%
model_pois = fit_poisson_glm(X, y, offset)
model_pois.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                ClaimNb   No. Observations:               678013
# Model:                            GLM   Df Residuals:                   678007
# Model Family:                 Poisson   Df Model:                            5
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -1.0807e+05
# Date:                Fri, 26 Dec 2025   Deviance:                   1.6537e+05
# Time:                        14:53:54   Pearson chi2:                 1.12e+06
# No. Iterations:                     7   Pseudo R-squ. (CS):           0.008732
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
